# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('noise-data.txt')

# %%
t = np.linspace(0.,536./44100.,num=537)

# %%
y = data[2:].astype(float).values.flatten()

# %%
ps = np.abs(np.fft.fft(y))**2
time_step = 1/44100.
freqs = np.fft.fftfreq(y.size, time_step)
idx = np.argsort(freqs)

# %%
#print(idx)
plt.plot(freqs[idx[268:268+50]],ps[idx[268:268+50]])
# Out:
# <img src="data:image/png;base64,..." width="967.4166666666666">
